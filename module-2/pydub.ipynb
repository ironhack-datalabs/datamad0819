# %%
from pydub import AudioSegment
from pydub.playback import play
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
import array

# %%
audio = AudioSegment.from_ogg("audio.ogg")
play(audio)
data_audio = audio.get_array_of_samples()
plt.plot(data_audio)

# %%
b, a = signal.butter(5, 1/10)
data_audio_filtered = signal.filtfilt(b, a, data_audio)
plt.plot(data_audio_filtered)

# %%
audio_filtered_array = array.array(audio.array_type, data_audio_filtered.astype(int))
audio_filtered = audio._spawn(audio_filtered_array)
play(audio_filtered)
