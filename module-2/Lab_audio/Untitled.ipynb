# %%
from pydub import AudioSegment

# %%
song = AudioSegment.from_gp("../labaudio.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-38bc2743d54a> in <module>
# ----> 1 song = AudioSegment.from_gp("../labaudio.gp")
#
# AttributeError: type object 'AudioSegment' has no attribute 'from_gp'
