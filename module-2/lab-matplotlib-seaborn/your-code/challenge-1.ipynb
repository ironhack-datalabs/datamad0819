# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

plt.subplot(2,1,1) 
plt.plot(x,y, color="g", lw=4, ls="--")
plt.subplot(2,1,2)
plt.plot(x,z,lw=10, color="r")

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig,axes=plt.subplots(1,2)
axes[0].plot(x,y,color="g", lw=3, ls='--')
axes[1].plot(x,z,color="r", lw=10, ls='-')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig,axes=plt.subplots(1,2, figsize=(12,10))
axes[0].plot(x,y,color="g", lw=8, ls='--')
axes[1].plot(x,z,color="r", lw=8, ls='-')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig,axes=plt.subplots(1,2, figsize=(20,10))

axes[0].plot(x,y,color="g", lw=3, ls='--')
axes[0].set_xlabel("eje X")
axes[0].set_ylabel("eje Y")

axes[1].plot(x,z,color="r", lw=3, ls='-')
axes[1].set_xlabel("eje X")
axes[1].set_ylabel("eje Z")
# Out:
# Text(0, 0.5, 'eje Z')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(15,5))
      
axes[0].plot(x, x**2,x, np.exp(x))
axes[1].set_yscale("linear")
axes[0].set_title("Linear scale")

axes[1].plot(x, x**2,x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
# Out:
# Text(0.5, 1.0, 'Logarithmic scale (y)')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
df = pd.read_csv('../your-code/vehicles.csv')
df.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100

# %%
# your code here

xf = df["Combined MPG"]
yf = df["Highway MPG"]
x = np.array([xf])
y = np.array([yf])

plt.scatter(x,y)

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
emision = df["CO2 Emission Grams/Mile"]

# %%
plt.boxplot(e)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a639d46da0>,
#   <matplotlib.lines.Line2D at 0x1a639d46eb8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a639d534a8>,
#   <matplotlib.lines.Line2D at 0x1a639d537f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a639d46978>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a639d53b38>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a639d53e80>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
fuel = df["Fuel Barrels/Year"]

# %%
plt.hist(fuel)
# Out:
# (array([8.1000e+01, 3.7400e+02, 6.7650e+03, 1.7039e+04, 8.9660e+03,
#         2.0960e+03, 5.6900e+02, 3.6000e+01, 2.1000e+01, 5.0000e+00]),
#  array([ 0.06      ,  4.76271429,  9.46542857, 14.16814286, 18.87085714,
#         23.57357143, 28.27628571, 32.979     , 37.68171429, 42.38442857,
#         47.08714286]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
x = df["Fuel Type"][0:20]
y = df["City MPG"][0:20]
xp = np.array(x)
yp = np.array(y)
xp
# Out:
# array(['Regular', 'Regular', 'Regular', 'Regular', 'Premium', 'Regular',
#        'Regular', 'Regular', 'Regular', 'Regular', 'Regular', 'Regular',
#        'Regular', 'Regular', 'Premium', 'Premium', 'Premium', 'Premium',
#        'Premium', 'Premium'], dtype=object)

# %%
bar = df[["City MPG", "Fuel Type"]].groupby(["Fuel Type"]).agg("sum")

# %%
bar.plot.bar()
