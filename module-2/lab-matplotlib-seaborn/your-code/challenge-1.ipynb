# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import math

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, y, color="red", linewidth=8)
plt.subplot(1, 2, 2)
plt.plot(x, z, color="black", linewidth=8)

plt.subplots_adjust(wspace=0.5)

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)

fig, axs = plt.subplots(1, 2)
axs[0].plot(x, y, color="pink", linewidth=8)
axs[1].plot(x, z, color="purple", linewidth=8)

plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here

fig, axs = plt.subplots(1, 2, figsize=[10, 6])
axs[0].plot(x, y, color="pink", linewidth=8)
axs[1].plot(x, z, color="purple", linewidth=8)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here

fig, axs = plt.subplots(1, 2, figsize=[10, 6])
axs[0].plot(x, y, color="orange", linewidth=8)
axs[1].plot(x, z, color="yellow", linewidth=8)

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

plt.subplots_adjust(wspace=0.3)

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

'''

plt.figure()
plt.subplot()
y = x**2
plt.plot(x, y, color="red")
ax.set_yscale("linear")

y = np.exp(x)
plt.plot(x, y, color="black")
ax.set_yscale("linear")


plt.subplot()
y = x**2
plt.plot(x, y, color="red")
ax.set_yscale("log")

y = np.exp(x)
plt.plot(x, y, color="black")
ax.set_yscale("log")

'''

#https://matplotlib.org/3.1.1/gallery/scales/scales.html#sphx-glr-gallery-scales-scales-py
# Out:
# '\n\nplt.figure()\nplt.subplot()\ny = x**2\nplt.plot(x, y, color="red")\nax.set_yscale("linear")\n\ny = np.exp(x)\nplt.plot(x, y, color="black")\nax.set_yscale("linear")\n\n\nplt.subplot()\ny = x**2\nplt.plot(x, y, color="red")\nax.set_yscale("log")\n\ny = np.exp(x)\nplt.plot(x, y, color="black")\nax.set_yscale("log")\n\n'

# %%
plt.subplot(1, 2, 1)

y = x**2
plt.plot(x, y)
ax.set_yscale("linear")

y = np.exp(x)
plt.plot(x, y)
ax.set_yscale("linear")

plt.subplot(1, 2, 2)

y = x**2
plt.plot(x, y)
ax.set_yscale("log")

y = np.exp(x)
plt.plot(x, y)
ax.set_yscale("log")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-6252a3c5f6b0> in <module>
# ----> 1 plt.subplot(1, 2, 1, figsize=[10, 6])
#       2
#       3 y = x**2
#       4 plt.plot(x, y)
#       5 ax.set_yscale("linear")
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      67
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#      71         # of the axis.  We need both because the axes may become smaller
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     507             self.set_yscale(yscale)
#     508
# --> 509         self.update(kwargs)
#     510
#     511         if self.xaxis is not None:
#
# /usr/local/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'AxesSubplot' object has no property 'figsize'

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here

vehicles = pd.read_csv("vehicles.csv")
vehicles.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x="Combined MPG", y="Highway MPG", data=vehicles)

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.figure(figsize=(20,15))
sns.boxplot(x=vehicles["CO2 Emission Grams/Mile"])

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.figure(figsize=(20,15))
sns.distplot(vehicles["Fuel Barrels/Year"])

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
plt.figure(figsize=(20,15))
sns.barplot(x="Fuel Type", y="City MPG", data=vehicles)
