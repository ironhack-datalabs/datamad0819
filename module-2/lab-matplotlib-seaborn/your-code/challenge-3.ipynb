# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv("titanic.csv",low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(exclude="object")[:10]
# Out:
#    PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.000000      1      0   7.2500
# 1            2       1.0       1  38.000000      1      0  71.2833
# 2            3       1.0       3  26.000000      0      0   7.9250
# 3            4       1.0       1  35.000000      1      0  53.1000
# 4            5       0.0       3  35.000000      0      0   8.0500
# 5            6       0.0       3  23.926502      0      0   8.4583
# 6            7       0.0       1  54.000000      0      0  51.8625
# 7            8       0.0       3   2.000000      3      1  21.0750
# 8            9       1.0       3  27.000000      0      2  11.1333
# 9           10       1.0       2  14.000000      1      0  30.0708

# %%
#your code here- categorical variable
titanic.select_dtypes(exclude=["number"])[:10]
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S
# 5            330877    U0        Q
# 6             17463   E46        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use("classic")
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
age = titanic["Age"]
plt.hist(age)
plt.ylabel("Total")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

plt.figure(figsize=(10,4))
plt.subplot(1, 3, 1)
plt.hist(age, bins=10)
plt.ylabel("Total")
plt.xlabel("Age")

plt.subplot(1, 3, 2)
plt.hist(age, bins=20)
plt.ylabel("Total")
plt.xlabel("Age")

plt.subplot(1, 3, 3)
plt.hist(age, bins=50)
plt.ylabel("Total")
plt.xlabel("Age")

plt.subplots_adjust(wspace=0.7)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#A la precisión.Cuanto mayor sea, por decirlo de alguna manera, la capacidad de cada contenedor, 
#se pierde el detalle de los datos.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic["Age"], bins=20, kde="False")

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way

titanic["Gender"].value_counts().plot(kind="bar")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# your code here- 2nd way
sns.countplot(x="Gender", data=titanic)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

titanic["Pclass"].value_counts().plot(kind="bar")
plt.ylabel("Total")
plt.xlabel("Class")
# Out:
# Text(0.5, 0, 'Class')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
fig1, ax1 = plt.subplots()
ax1.set_title("Age")
ax1.boxplot(titanic["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12351be48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12351b080>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12351b630>],
#  'medians': [<matplotlib.lines.Line2D at 0x123540358>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1235400b8>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
# La edad media de los viajeros se sitúa entre los 25 y los 30 años. Más cerca de estos útimos.
# El valor mínimo, en cero, y el máximo cerca de los 80. Los límites del cuadrado indican los quartiles

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
plt.figure(figsize=(10,4))
plt.hist(age, bins=50)
plt.ylabel("Total")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# Una información más precisa sobre la distribución de la media de edad. En este gráfico se puede 
# observar que los grupos más numerosos agrupados por edad se sitúan justo en la frontera
# de los 30 y por debajo de los 25.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.lmplot(x="Fare", y="Age", data=titanic)

# %%
# your code-2nd way

fare = titanic["Fare"]
age = titanic["Age"]

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_select = titanic[["PassengerId", "Survived", "Pclass", "Age", "SibSp", "Parch", "Fare"]]
sns.heatmap(titanic_select.corr(), cmap="YlGnBu")

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
# La tarifa y la supervivencia. Y los parametros que dan cuenta de las relaciones entre
# niños y hermanos que subieron al barco (Parch, SibSp)

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x="Pclass", y="Age", data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col="Gender")
g = g.map(plt.hist, "Age")
