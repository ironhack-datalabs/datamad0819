# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import codex
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
import re
# import scrapy
from PIL import Image
from io import BytesIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-156-b6be802fc7b0> in <module>
#       2 from bs4 import BeautifulSoup
#       3 import pandas as pd
# ----> 4 import codex
#       5 # from pprint import pprint
#       6 # from lxml import html
#
# ModuleNotFoundError: No module named 'codex'

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
request = requests.get(url)
request.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(request.text,"html5lib")
del request
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#
#
#
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-6b8b7859c4b8fbe3ab45f8ab0905a9f8.css" integrity="sha512-aVn2DoCuXdXX9G3sp/Luupl/Ui00/iXrUh7Ke3geLlkigQY8GHBky7kKRSuyeKxGApWDdCQUy+6gTF1ZmYHWkw==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your codeso
a="h3 lh-condensed"
#soup.select("h1 # h3 lh-condensed")
soupNombres = soup.find_all("h1",class_=a )
soupNombres
# Out:
# [<h1 class="h3 lh-condensed"><a href="/vitorgalvao">Vítor Galvão</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/mpociot">Marcel Pociot</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/guardrex">Luke Latham</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/fzaninotto">Francois Zaninotto</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/balloob">Paulus Schoutsen</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/vadimdemedes">Vadim Demedes</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/plouc">Raphaël Benitte</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/johno">John Otander</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/mercyblitz">Mercy Ma</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/hpdang">Hong Phuc Dang</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/hishamhm">Hisham Muhammad</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/dcodeIO">Daniel Wirtz</a></h1>,
#  <h1 class="h3 lh-condensed"><a href="/edenhill">Magnus Edenhill</a></h1>,
# ...

# %%
def cleanName(ele):
    
    no1,no2,si = str(ele).replace('"',"'").split("'>")
    return si

# %%
listNombres = list(map(cleanName,soupNombres))
listNombres = list(map(lambda string: string.replace("</a></h1>",""),listNombres))
listNombres
# Out:
# ['Vítor Galvão',
#  'Marcel Pociot',
#  'Luke Latham',
#  'Francois Zaninotto',
#  'Paulus Schoutsen',
#  'Vadim Demedes',
#  'Raphaël Benitte',
#  'John Otander',
#  'Mercy Ma',
#  'Hong Phuc Dang',
#  'Hisham Muhammad',
#  'Daniel Wirtz',
#  'Magnus Edenhill',
#  'Mike Perham',
#  'Daniel Martí',
#  'Kevin Papst',
#  'Thomas Lin Pedersen',
#  'Rakan Nimer',
#  'Raphaël Huchet',
#  'Andrew Gallant',
#  'Sheng Chen',
#  'Harry',
#  'Sean McArthur',
#  'Rob Dodson',
#  'Andrew Arnott']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
requestRep = requests.get(url)
print(requestRep.status_code)
soupRep = BeautifulSoup(requestRep.text,"html5lib")
del requestRep
# Out:
# 200

# %%
#your code
a="h3 lh-condensed"
#soup.select("h1 # h3 lh-condensed")
listRep = soupRep.find_all("h1",class_=a )

listRep = list(map((lambda ele:re.findall('href=.+>',str(ele))[0]),listRep))
def cleanRepos(string):
    no1,si,no2 = string.split('"')
    return si
listRep = list(map(cleanRepos,listRep))
listRep
# Out:
# ['/testerSunshine/12306',
#  '/Yorko/mlcourse.ai',
#  '/iperov/DeepFaceLab',
#  '/ckiplab/ckiptagger',
#  '/tensorflow/neural-structured-learning',
#  '/insilicomedicine/GENTRL',
#  '/hudson-and-thames/mlfinlab',
#  '/deepfakes/faceswap',
#  '/CorentinJ/Real-Time-Voice-Cloning',
#  '/deepinsight/insightface',
#  '/zhaipro/easy12306',
#  '/keras-team/keras',
#  '/mne-tools/mne-python',
#  '/pjialin/py12306',
#  '/xadrianzetx/fullstack.ai',
#  '/ansible/awx',
#  '/s3nh/pytorch-text-recognition',
#  '/alexmojaki/heartrate',
#  '/RaRe-Technologies/gensim',
#  '/open-mmlab/mmdetection',
#  '/tensorflow/models',
#  '/Azure/azure-cli',
#  '/nprapps/heat-income',
#  '/zalandoresearch/flair',
#  '/iGhibli/iOS-DeviceSupport']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %% [markdown]
# #response = requests.get(url)
# #img = Image.open(BytesIO(response.content))
# <img alt=""  class="thumbimage"

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
requestImg = requests.get(url)
print(requestImg.status_code)
soupImg = BeautifulSoup(requestImg.text,"html5lib")
del requestImg
# Out:
# 200

# %%
#your code <a href="/wiki/File:Disney1968.jpg" class="image"><img a
listImg = soupImg.find_all("a",class_="image" )

listImg = [str(ele) for ele in listImg]
listImg = "".join(listImg)
listImg = BeautifulSoup(listImg,"html.parser")
#listImg = soupImg.find_all("src")
listUrlImg = []
for ele in listImg:
    listUrlImg.append(ele.find("img").get("src"))
listUrlImg = [str(ele)[2:] for ele in listUrlImg]
listUrlImg
# Out:
# ['upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
requestImg = requests.get(url)
print(requestImg.status_code)
soupPy = BeautifulSoup(requestImg.text,"html5lib")
del requestImg
# Out:
# 200

# %%
python = soupPy.find_all("ul")
listapy = [(ele.find("a")) for ele in python]
listapy = [str(ele) for ele in listapy]
def cleanPy(string):
    try:
        no,si,no = string.split('"',2)
        return si
    except:
        return None

listapy=list(map(cleanPy,listapy))
listapy=[ele for ele in listapy if ele not in ["n","c",None,"z","j"]]
listapy
# Out:
# ['#Snakes',
#  '#Roller_coasters',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_(film)',
#  '/wiki/Pythons_2',
#  '/wiki/Python_(Monty)_Pictures',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  '/wiki/Python_(automobile_maker)',
#  '/wiki/Colt_Python',
#  '/wiki/Python_Anghelo',
#  '/wiki/PYTHON',
#  '/wiki/Cython',
#  '/wiki/Category:Disambiguation_pages',
#  '/wiki/Category:Disambiguation_pages_with_short_description',
#  '/wiki/Python',
#  '/wiki/Help:Contents',
#  'https://commons.wikimedia.org/wiki/Category:Python',
#  '/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Python',
#  'interlanguage-link-target',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  'extiw',
#  'https://wikimediafoundation.org/']

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'
#<div class="usctitlechanged" id="us/usc/t11">
#your code
requestUsa = requests.get(url)
print(requestUsa.status_code)
soupUsa = BeautifulSoup(requestUsa.text,"html5lib")
del requestUsa
# Out:
# 200

# %%
#your code
stringUsa = soupUsa.select("div .usctitlechanged")
stringUsa = [(str(ele)).replace(" ","") for ele in stringUsa]
def cleanUsa(string):
    no,si,no = string.split("\n\n")
    return si
stringUsa = list(map(cleanUsa,stringUsa))
stringUsa = list(map(lambda string: (string.split("<",1))[0],stringUsa))
stringUsa
# Out:
# ['Title5-GovernmentOrganizationandEmployees',
#  'Title11-Bankruptcy',
#  'Title20-Education',
#  'Title28-JudiciaryandJudicialProcedure',
#  "Title38-Veterans'Benefits",
#  'Title42-ThePublicHealthandWelfare']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'
requestFbi = requests.get(url)
print(requestFbi.status_code)
soupFbi = BeautifulSoup(requestFbi.text,"html5lib")
# Out:
# 200

# %%
#your code  
stringfbi = soupFbi.select("img[alt]")

# %%
def cleanFbi(ele):
    return ((str(ele)).split("=",2))[1]

stringfbi = list(map(cleanFbi,stringfbi))

# %%
stringfbi = list(map((lambda string:string.replace('"',"")),stringfbi))
stringfbi = list(map((lambda string:string.replace(' class',"")),stringfbi))
stringfbi.remove(stringfbi[0])
stringfbi
# Out:
# ['YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'
request = requests.get(url)
print(request.status_code)
soup = BeautifulSoup(request.text,"html5lib")
# Out:
# 200

# %%
#your code
terremotos = soup.select("tr[onclick]")

#fechas = [str(ele.select("a")).split(">")[-2] for ele in terremotos]

# %%
lfecha=[]
lhora=[]
lLat=[]
lLon=[]
lReg=[]
for i in range(20):
    fechaHora = str(terremotos[i].select("a")).split('"')[-1]
    fecha, hora = (fechaHora.split("\xa0\xa0\xa0"))
    
    fecha = str(fecha[1:])
    fecha = str(fecha)
    lfecha.append(fecha)
    hora = str(hora).split('<')[0]
    lhora.append(hora)
    
    lat,long =(terremotos[i].find_all("td",class_="tabev1"))
    ns,ew,m = (terremotos[i].find_all("td",class_="tabev2"))
    region = (terremotos[i].find_all("td",class_="tb_region"))
    
    lat = (str(lat).split('>')[-2]).split("\xa0")[0]
    long = (str(long).split('>')[-2]).split("\xa0")[0]
    ns = (str(ns).split('>')[-2]).split("\xa0")[0]
    ew = (str(ew).split('>')[-2]).split("\xa0")[0]
    
    lLat.append(lat+ns)
    lLon.append(long+ew)
    region = str((str(region).split('>')[-2])).split('<')[0].split('\xa0')[-1]
    lReg.append(region)
listaCol = [lfecha,lhora,lLat,lLon,lReg]
listaInd = ["fecha","hora","Latitud","Longitud","Region"]
df = pd.DataFrame()

for i in range(len(listaCol)):
    df[listaInd[i]]=listaCol[i]
df
# Out:
#          fecha        hora Latitud Longitud                            Region
# 0   2019-09-06  09:00:30.9  36.52N   27.85E  DODECANESE IS.-TURKEY BORDER REG
# 1   2019-09-06  08:59:55.6  35.77N   31.70E                     CYPRUS REGION
# 2   2019-09-06  08:24:17.0  36.12N    7.68W               STRAIT OF GIBRALTAR
# 3   2019-09-06  08:21:57.5  29.73S   71.74W          OFFSHORE COQUIMBO, CHILE
# 4   2019-09-06  08:05:05.5  42.80N   13.14E                     CENTRAL ITALY
# 5   2019-09-06  08:00:02.6  35.76N  117.56W               SOUTHERN CALIFORNIA
# 6   2019-09-06  07:46:32.0   7.74S  118.95E                        FLORES SEA
# 7   2019-09-06  07:34:58.1  37.06N  121.10W                CENTRAL CALIFORNIA
# 8   2019-09-06  07:28:59.0   3.23N  127.00E       KEPULAUAN TALAUD, INDONESIA
# 9   2019-09-06  07:25:35.9  28.66N  104.81E            EASTERN SICHUAN, CHINA
# 10  2019-09-06  06:49:34.9  35.92N  117.69W                CENTRAL CALIFORNIA
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'
request = requests.get(url)
print(request.status_code)
soup = BeautifulSoup(request.text,"html5lib")
# Out:
# 200

# %%
#your code
hack = soup.select("div .card-body")

# %%
listaCol = [[],[],[]]
for ele in hack:
    nombre = (str(ele.select("h5")[0])).split('"')[2][1:].split('<')[0]
    fecha,lugar= str(ele.find("p").text).replace('\n'," ").replace("  ","")[1:].split("\u2003")
    listaCol[0].append(nombre)
    listaCol[1].append(fecha)
    listaCol[2].append(lugar)
    
listaIndex = ["Nombre","Fecha","Lugar"]
df = pd.DataFrame()
for i in range(len(listaIndex)):
    df[listaIndex[i]]= listaCol[i]
df
# Out:
#                     Nombre      Fecha                   Lugar
# 0          TECHFEST MUNICH   9/6/2019         Munich, Germany
# 1  Galileo App Competition  1/31/2019  Prague, Czech Republic

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
request = requests.get(url)
print(request.status_code)
soup = BeautifulSoup(request.text,"html5lib")
# Out:
# 200

# %%
wiki = soup.select("div[class~=central-featured]")
wiki = wiki[0].select("a[class~=link-box]")
lista=[]
for ele in wiki:
    idioma = str(ele.select("strong")[0].text)
    articu = str(ele.select("bdi")[0].text)
    print(idioma,articu)
# Out:
# English 5 915 000+
# æ¥æ¬èª 1 165 000+
# EspaÃ±ol 1 539 000+
# Deutsch 2 336 000+
# Ð ÑÑÑÐºÐ¸Ð¹ 1 564 000+
# FranÃ§ais 2 134 000+
# Italiano 1 549 000+
# ä¸­æ 1 070 000+
# PortuguÃªs 1 012 000+
# Polski 1 353 000+

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
#your code
request = requests.get(url)
print(request.status_code)
soup = BeautifulSoup(request.text,"html5lib")
# Out:
# 200

# %%
datasets = soup.select("h2")
lista = []
for ele in datasets:
    lista.append(ele.find("a").text)
print(lista)
# Out:
# ['Business and economy', 'Crime and justice', 'Defence', 'Education', 'Environment', 'Government', 'Government spending', 'Health', 'Mapping', 'Society', 'Towns and cities', 'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your wikitable sortable jquery-tablesorter
request = requests.get(url)
print(request.status_code)
soup = BeautifulSoup(request.text,"html5lib")
# Out:
# 200

# %%
topL = soup.select("table")[0]
topL =topL.select("a[href]")
lista = []
for i in range(3,34):
    
    idioma = str(topL[i].text)
    lista.append(idioma)
newL=[]
for i in range(len(lista)):
    if lista[i].find('[')!=-1:
        i = i+1
    else:
        newL.append(lista[i])
        
newL
# Out:
# ['Mandarin',
#  'China',
#  'Sino-Tibetan',
#  'Sinitic',
#  'Spanish',
#  'Spain',
#  'Indo-European',
#  'Romance',
#  'English',
#  'United Kingdom',
#  'Indo-European',
#  'Germanic',
#  'Hindi',
#  'India',
#  'Indo-European',
#  'Indo-Aryan',
#  'Bengali',
#  'Bangladesh',
#  'Indo-European',
#  'Indo-Aryan',
#  'Portuguese',
#  'Portugal',
#  'Indo-European',
#  'Romance',
#  'Russian',
#  'Russian Federation',
#  'Indo-European',
#  'Balto-Slavic',
#  'Japanese']

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
