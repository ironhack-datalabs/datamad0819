# %%
import pandas as pd
import numpy as np

# %%
#Importamos el csv
# Out:
# 20

# %%
sharks_df = pd.read_csv('../your-code/input/GSAF5.csv',encoding='utf-8')

# %%
#pd.set_option('max_rows', 5992) 

#Seleccionamos el número máximo de filas para poder tener todo el df, hemos conocido el número de filas printeando
#previamente df

# %%
sharks_df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
sharks_df.columns #Sabemos las columnas del dataframe
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks_df.isnull() #Conocemos todos aquellos valores nulos y no nulos del dataframe
# Out:
#       Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0           False  False  False  False    False  False     False     False
# 1           False  False  False  False    False  False     False     False
# 2           False  False  False  False    False  False     False     False
# 3           False  False  False  False    False  False     False     False
# 4           False  False  False  False    False  False     False     False
# 5           False  False  False  False    False  False     False     False
# 6           False  False  False  False    False  False     False     False
# 7           False  False  False  False    False  False     False     False
# 8           False  False  False  False    False  False     False     False
# 9           False  False  False  False    False  False     False     False
# 10          False  False  False  False    False  False     False     False
# ...

# %%
sharks_df.isnull().sum().sum    #Sumatorio nulos
# Out:
# <bound method Series.sum of Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64>

# %%
sharks_clean = sharks_df.drop(['pdf','href formula','href','Unnamed: 22','Unnamed: 23'], axis=1)

sharks_clean #Eliminamos columnas sin valor para nuestro análisis.
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
sharks_clean.isnull()
# Out:
#       Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0           False  False  False  False    False  False     False     False
# 1           False  False  False  False    False  False     False     False
# 2           False  False  False  False    False  False     False     False
# 3           False  False  False  False    False  False     False     False
# 4           False  False  False  False    False  False     False     False
# 5           False  False  False  False    False  False     False     False
# 6           False  False  False  False    False  False     False     False
# 7           False  False  False  False    False  False     False     False
# 8           False  False  False  False    False  False     False     False
# 9           False  False  False  False    False  False     False     False
# 10          False  False  False  False    False  False     False     False
# ...

# %%
#Vamos a intentar ver dónde se han producido más ataques de tiburón,
#En USA o en Australia, ya que son comúnmente los países en los que
#más ataques de tiburón blanco se producen https://www.thesun.co.uk/travel/8575104/countries-shark-attacks-2018/

# %%
display(sharks_clean.drop_duplicates()) #Eliminamos duplicados
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
sharks_df1 = sharks_clean.drop(columns=['Name','Sex ','Age','Investigator or Source','Case Number.1','Case Number.2','Time','Injury','Species '])

#Eliminamos columnas que no son relevantes para nuestro análisis

sharks_df1
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
sharks_df1.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity Fatal (Y/N)  original order
# 0  New Smyrna Beach, Volusia County  Surfing           N            5993
# 1  New Smyrna Beach, Volusia County  Surfing           N            5992
# 2  New Smyrna Beach, Volusia County  Surfing           N            5991
# 3                  Thirteenth Beach  Surfing           N            5990
# 4                       Bells Beach  Surfing           N            5989

# %%
#Dentro de Acitivty sustituimos aquellos valores vacíos.

# %%
sharks_df1['Activity'].fillna('Unknown', inplace = True)

 #Sacamos una lista de las actividades que estaban realizando antes del ataque.

print(set(sharks_df1['Activity']))
# Out:
# {'Helmet diving, collecting trochus shell', 'Washing', 'Vessel capsized, wading ashore carrying an oar', 'ship torpedoed 400 miles off the African coas. Man was clinging to hatch cover', 'Swimming or surfing', 'Swimming after being washed overboard', 'Floating face-down in knee-deep water', 'Free-diving', 'Snorkeling on surface', "63' fishing boat Sno' Bay foundered", 'wreck of the State Oil Company ship Permina', 'Canoe capsized by shark', 'Collecting shells', 'native boats sunk in storm', 'Netting sharks', 'Crabbing (spearing crabs)', 'Jerked overboard while pole fishing for tuna', 'Surf fishing, wading ', 'Leaving the water', 'Surfing with dolphins', 'Spearfishing / freediving', 'Free diving, surveying a pipeline & examing cathodes under jetty', 'Wading / fishing & carrying a bag of fish', 'Swimming with motor tube', 'Swimming / surfing', 'The steamship Bonnie Dundee lost in collision', 'Bathing alongside the American ship Thomas W. Sears', 'Lying atop surfboard', 'Diving from the
# ...

# %%
activity = sharks_df1['Activity'].tolist()

# %%
def counterTypes(tipo):
    counted = activity.count(tipo)
    print("Shark Attack :" ,i, counted)

for i in lista:
    counterTypes(i)
    
#Con la función hacemos que se cuente la cantidad de ataques que se han producido por tipo.
# Out:
# Shark Attack : Helmet diving, collecting trochus shell 1
# Shark Attack : Washing 2
# Shark Attack : Vessel capsized, wading ashore carrying an oar 1
# Shark Attack : ship torpedoed 400 miles off the African coas. Man was clinging to hatch cover 1
# Shark Attack : Swimming or surfing 2
# Shark Attack : Swimming after being washed overboard 1
# Shark Attack : Floating face-down in knee-deep water 1
# Shark Attack : Free-diving 2
# Shark Attack : Snorkeling on surface 1
# Shark Attack : 63' fishing boat Sno' Bay foundered 1
# Shark Attack : wreck of the State Oil Company ship Permina 1
# Shark Attack : Canoe capsized by shark 1
# Shark Attack : Collecting shells 2
# Shark Attack : native boats sunk in storm 1
# Shark Attack : Netting sharks 1
# Shark Attack : Crabbing (spearing crabs) 1
# Shark Attack : Jerked overboard while pole fishing for tuna 1
# Shark Attack : Surf fishing, wading  1
# Shark Attack : Leaving the water 1
# Shark Attack : Surfing with dolphins 1
# ...

# %%
sharks_filter = sharks_df1[(sharks_df1['Activity']=='Surfing')]
display(sharks_filter)

#Sacamos únicamente los ataques que han ocurrido mientras se realizaba surf.
# Out:
#        Case Number                  Date  Year        Type  \
# 0     2016.09.18.c             18-Sep-16  2016  Unprovoked
# 1     2016.09.18.b             18-Sep-16  2016  Unprovoked
# 2     2016.09.18.a             18-Sep-16  2016  Unprovoked
# 3       2016.09.17             17-Sep-16  2016  Unprovoked
# 4       2016.09.15             16-Sep-16  2016  Unprovoked
# 10    2016.09.05.a             05-Sep-16  2016  Unprovoked
# 13    2016.08.29.b             29-Aug-16  2016  Unprovoked
# 14    2016.08.29.a             29-Aug-16  2016  Unprovoked
# 15      2016.08.27             27-Aug-16  2016  Unprovoked
# 19      2016.08.04             04-Aug-16  2016  Unprovoked
# 24      2016.07.26             26-Jul-16  2016  Unprovoked
# 25      2016.07.24             24-Jul-16  2016  Unprovoked
# 26    2016.07.23.b             23-Jul-16  2016  Unprovoked
# 30    2016.07.16.b             16-Jul-16  2016  Unprovoked
# 41      2016.06.25             25-Jun-16  2016  Unprovoked
# ...

# %%
print(sharks_filter['Type'].value_counts())
# Out:
# Unprovoked    857
# Invalid        36
# Provoked       11
# Name: Type, dtype: int64

# %%
tipo = sharks_filter['Type'].tolist()
cambios = {'Invalid':'Unprovoked','Boat':'Unprovoked','Sea Disaster':'Unprovoked'}

print(tipo)

#Cambiamos las actividades que no son provocadas por 'Unprovoked'
# Out:
# ['Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Invalid', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Invalid', 'Invalid', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Invalid', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Invalid', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Invalid', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Invalid', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoked', 'Unprovoke
# ...

# %%
sharks_df2 = sharks_filter[(sharks_filter['Activity']=='Surfing') & (sharks_filter['Country']=='AUSTRALIA') & (sharks_filter['Type']=='Unprovoked')] 

display(sharks_df2)
display(sharks_df2.shape)

#Filtramos los no provocados en Australia.
# Out:
#        Case Number                  Date  Year        Type    Country  \
# 3       2016.09.17             17-Sep-16  2016  Unprovoked  AUSTRALIA
# 4       2016.09.15             16-Sep-16  2016  Unprovoked  AUSTRALIA
# 10    2016.09.05.a             05-Sep-16  2016  Unprovoked  AUSTRALIA
# 24      2016.07.26             26-Jul-16  2016  Unprovoked  AUSTRALIA
# 26    2016.07.23.b             23-Jul-16  2016  Unprovoked  AUSTRALIA
# 56      2016.05.31             31-May-16  2016  Unprovoked  AUSTRALIA
# 77      2016.03.30             30-Mar-16  2016  Unprovoked  AUSTRALIA
# 79    2016.03.28.a             28-Mar-16  2016  Unprovoked  AUSTRALIA
# 100   2016.01.11.R  Reported 11-Jan-2016  2016  Unprovoked  AUSTRALIA
# 106   2015.12.21.b             21-Dec-15  2015  Unprovoked  AUSTRALIA
# 115     2015.11.10             10-Nov-15  2015  Unprovoked  AUSTRALIA
# 132     2015.10.07             07-Oct-15  2015  Unprovoked  AUSTRALIA
# ...

# %%
sharks_provokedAUS = sharks_filter[(sharks_filter['Activity']=='Surfing') & (sharks_filter['Country']=='AUSTRALIA') & (sharks_filter['Type']=='Provoked')] 

display(sharks_provoked)

display(sharks_provokedAUS.shape)

#Filtramos provocados en Asutralia.
# Out:
#      Case Number       Date  Year      Type    Country             Area  \
# 259   2014.10.30  29-Oct-14  2014  Provoked  AUSTRALIA  New South Wales
# 3514  1963.09.13  13-Sep-63  1963  Provoked  AUSTRALIA  New South Wales
#
#            Location Activity          Name Sex  Age  \
# 259   Wallabi Point  Surfing     Ryan Hunt    M  20
# 3514    Wanda Beach  Surfing  Peter Barron    M  18
#
#                                                  Injury Fatal (Y/N)   Time  \
# 259   Laceration to dorsum of left foot when he step...           N  18h00
# 3514  A "dead" shark grabbed by the tail bit his rig...           N  09h30
#
#               Species                             Investigator or Source  \
# 259                NaN             The Sydney Morning Herald, 10/30/2014
# 3514  1.5 m [5'] shark  P. Barron; Goulburn Evening Post; J. Green, p.35
#
#      Case Number.1 Case Number.2  original order
# 259     2014.10.30    2014.10.30            5734
# ...

# %%
#Los ataques en AUS son 160 / 2  => No provocados / Provocados

# %%
sharks_df3 = sharks_filter[(sharks_filter['Activity']=='Surfing') & (sharks_filter['Country']=='USA') & (sharks_filter['Type']=='Unprovoked')] 

display(sharks_df3)

display(sharks_df3.shape)


#Filtramos por los no provocados en USA.
# Out:
#        Case Number                  Date  Year        Type Country  \
# 0     2016.09.18.c             18-Sep-16  2016  Unprovoked     USA
# 1     2016.09.18.b             18-Sep-16  2016  Unprovoked     USA
# 2     2016.09.18.a             18-Sep-16  2016  Unprovoked     USA
# 13    2016.08.29.b             29-Aug-16  2016  Unprovoked     USA
# 14    2016.08.29.a             29-Aug-16  2016  Unprovoked     USA
# 19      2016.08.04             04-Aug-16  2016  Unprovoked     USA
# 30    2016.07.16.b             16-Jul-16  2016  Unprovoked     USA
# 41      2016.06.25             25-Jun-16  2016  Unprovoked     USA
# 46    2016.06.15.b             15-Jun-16  2016  Unprovoked     USA
# 67      2016.04.23             23-Apr-16  2016  Unprovoked     USA
# 95      2016.01.28             28-Jan-16  2016  Unprovoked     USA
# 96      2016.01.25             25-Jan-16  2016  Unprovoked     USA
# 112     2015.11.16             16-Nov-15  2015  Unprovoked     USA
# ...

# %%
sharks_provokedUSA = sharks_filter[(sharks_filter['Activity']=='Surfing') & (sharks_filter['Country']=='USA') & (sharks_filter['Type']=='Provoked')] 

display(sharks_provokedUSA)
display(sharks_provokedUSA.shape)
# Out:
#        Case Number          Date  Year      Type Country        Area  \
# 402   2013.09.07.b   07-Sep-2013  2013  Provoked     USA     Florida
# 1009    2008.07.23     23-Jul-08  2008  Provoked     USA     Florida
# 1044  2008.04.26.a     26-Apr-08  2008  Provoked     USA     Florida
# 1510  2003.10.05.c     05-Oct-03  2003  Provoked     USA     Florida
# 1551    2003.05.07     07-May-03  2003  Provoked     USA     Florida
# 1618    2002.07.10     10-Jul-02  2002  Provoked     USA     Florida
# 1920    1998.12.24     24-Dec-98  1998  Provoked     USA     Florida
# 3417  1965.00.00.f          1965  1965  Provoked     USA  California
# 4058  1955.08.30.a     30-Aug-55  1955  Provoked     USA  California
#
#                                            Location Activity Fatal (Y/N)  \
# 402               New Smyrna Beach,  Volusia County  Surfing           N
# 1009               New Smyrna Beach, Volusia County  Surfing           N
# ...

# %%
#Los ataques en EEUU son en su mayoría no provocados en un 502 / 9

# %%
#Podemos llegar a la conlucisón de que hay más ataques no provocados que provocados.
#Se producen más ataques provocados en EEUU. La causa puede ser que hay más cantidad de surferos.

# %%
sharks_filter.to_csv('Notbabysharks.csv')
