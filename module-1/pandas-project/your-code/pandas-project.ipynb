# %%
import pandas as pd

# %%
df = pd.read_csv("../input/GSAF5.csv", encoding="ISO-8859-1")
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
df = df.rename(columns={"Case Number.1": "Uno", "Case Number.2": "Dos", "href formula": "hformula"})  

"""" Renombramos las columnas "Case Number.1" y "Case Number.2", para que sea mas facil trabajar con ellas"""
# Out:
# '" Renombramos las columnas "Case Number.1" y "Case Number.2", para que sea mas facil trabajar con ellas'

# %%
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
null_cols = df.isnull().sum()
null_cols[null_cols>0]                 #Comprobamos las columnas que tienen elementos nulos
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
drop_cols = (null_cols[null_cols > 5000].index)
df = df.drop(drop_cols, axis=1)                         #eliminamos las columnas que son enteras nulas
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
s = df.Uno
s = s.values
print (s)
# Out:
# ['2016.09.18.c' '2016.09.18.b' '2016.09.18.a' ... 'ND.0003' 'ND.0002'
#  'ND.0001']

# %%
d = df.Dos
d = d.values
print (d)
# Out:
# ['2016.09.18.c' '2016.09.18.b' '2016.09.18.a' ... 'ND.0003' 'ND.0002'
#  'ND.0001']

# %%
lista = 0
for x in d:
    for y in s:
        if x == y:
            lista += 1

# %%
lista 

""""vemos que gran parte de los valores en la columna "Uno" y "Dos" estan repetidos, por lo que vamos
a eliminar la columna "dos". """
# Out:
# 6014

# %%
df = df.drop(["Dos"], axis=1)
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
before = len(df)
df = df.drop_duplicates()             #vemos que no hay filas duplicadas integramente
after = len(df)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
href = df.href
hrefval = href.values
hrefval
# Out:
# array(['http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.c-NSB.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.b-Luciano.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.a-NSB.pdf',
#        ...,
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0003-Ocracoke_1900-1905.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0002-JulesPatterson.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directoryND-0001-Ceylon.pdf'],
#       dtype=object)

# %%
hrefor = df.hformula
hreforval = hrefor.values
hreforval
# Out:
# array(['http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.c-NSB.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.b-Luciano.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.a-NSB.pdf',
#        ...,
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0003-Ocracoke_1900-1905.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0002-JulesPatterson.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directoryND-0001-Ceylon.pdf'],
#       dtype=object)

# %%
lista1 = 0
for x in hrefval:
    for y in hreforval:
        if x == y:
            lista1 += 1

# %%
lista1
# Out:
# 5963

# %%
""""vemos que las columnas "href" y "href formula" tienen tambien muchos valores en comun, por lo que eliminamos una de ellas"""

# %%
df = df.drop(["hformula"], axis=1)
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
year = df["Year"].value_counts()
year
# Out:
# 2015    139
# 2011    128
# 2014    125
# 0       124
# 2013    122
# 2008    121
# 2009    120
# 2012    117
# 2007    112
# 2006    103
# 2016    103
# 2005    103
# 2010    101
# 2000     97
# 1959     93
# 1960     93
# 2001     92
# 2004     92
# 2003     92
# 2002     88
# 1962     86
# 1961     78
# 1995     76
# 1964     66
# 1998     65
# 1999     65
# 1996     61
# 1963     61
# 1966     58
# 1997     57
#        ...
# 1785      1
# 1834      1
# 1791      1
# 1733      1
# 1721      1
# 1637      1
# 1617      1
# 77        1
# 5         1
# 1703      1
# 1755      1
# 1767      1
# 1771      1
# 1779      1
# 1787      1
# 1803      1
# 1749      1
# 1807      1
# 1811      1
# 1819      1
# 1805      1
# 1831      1
# 1555      1
# 1738      1
# 1859      1
# 1742      1
# 1758      1
# 1818      1
# 1822      1
# 1595      1
# Name: Year, Length: 232, dtype: int64

# %%
df2 = df.drop(df[(df.Year < 1959)].index)
df2
# Out:
#         Case Number                  Date  Year        Type  \
# 0      2016.09.18.c             18-Sep-16  2016  Unprovoked
# 1      2016.09.18.b             18-Sep-16  2016  Unprovoked
# 2      2016.09.18.a             18-Sep-16  2016  Unprovoked
# 3        2016.09.17             17-Sep-16  2016  Unprovoked
# 4        2016.09.15             16-Sep-16  2016  Unprovoked
# 5      2016.09.15.R             15-Sep-16  2016        Boat
# 6        2016.09.11             11-Sep-16  2016  Unprovoked
# 7        2016.09.07             07-Sep-16  2016  Unprovoked
# 8        2016.09.06             06-Sep-16  2016  Unprovoked
# 9      2016.09.05.b             05-Sep-16  2016  Unprovoked
# 10     2016.09.05.a             05-Sep-16  2016  Unprovoked
# 11       2016.09.04             04-Sep-16  2016  Unprovoked
# 12       2016.09.01             01-Sep-16  2016  Unprovoked
# 13     2016.08.29.b             29-Aug-16  2016  Unprovoked
# 14     2016.08.29.a             29-Aug-16  2016  Unprovoked
# ...

# %%
year2 = df2["Year"].value_counts()
year2
# Out:
# 2015    139
# 2011    128
# 2014    125
# 2013    122
# 2008    121
# 2009    120
# 2012    117
# 2007    112
# 2006    103
# 2016    103
# 2005    103
# 2010    101
# 2000     97
# 1959     93
# 1960     93
# 2004     92
# 2003     92
# 2001     92
# 2002     88
# 1962     86
# 1961     78
# 1995     76
# 1964     66
# 1999     65
# 1998     65
# 1963     61
# 1996     61
# 1966     58
# 1997     57
# 1993     56
# 1992     56
# 1994     56
# 1988     55
# 1989     53
# 1965     51
# 1983     50
# 1981     49
# 1975     49
# 1967     48
# 1968     46
# 1970     42
# 1984     41
# 1982     40
# 1976     39
# 1986     39
# 1991     38
# 1990     38
# 1974     38
# 1985     37
# 1980     35
# 1972     35
# 1987     35
# 1969     30
# 1971     28
# 1973     27
# 1977     26
# 1978     25
# 1979     25
# Name: Year, dtype: int64

# %%
type = df2["Type"].value_counts()
type
# Out:
# Unprovoked      2933
# Provoked         368
# Invalid          332
# Boat             187
# Sea Disaster      81
# Name: Type, dtype: int64

# %%
act = df2["Activity"].value_counts()
act.head()
# Out:
# Surfing         891
# Swimming        467
# Spearfishing    278
# Fishing         219
# Wading          122
# Name: Activity, dtype: int64

# %%
pais = df2["Country"].value_counts()
pais.head()
# Out:
# USA             1693
# AUSTRALIA        668
# SOUTH AFRICA     423
# BRAZIL            95
# BAHAMAS           81
# Name: Country, dtype: int64
