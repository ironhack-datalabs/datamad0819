# %% [markdown]
# # Global Shark Attack Incidents
#
# ## First pandas proyect
#
#  ### Step 1.- Data acquisition:

# %%
import pandas as pd
import numpy as np
import re
from modules.functions import *

# %%
# At importing dataset it is necessary to change encoding to open it.
# It is not encoded as utf-8, so it is necessary to open it with the correct encoding.
df = pd.read_csv('input/GSAF5.csv',encoding= 'iso-8859-1')

# %% [markdown]
# ### Step 2.- Data cleaning:
#
# The first thing that will be done is to do an overvierw of what kind of data do we have and the quality of It.

# %%
'''
Let's set the options to be able to see all clomuns while printing our dataset. 
'''
pd.set_option('display.max_columns', 24)
'''
Afterwrds lets check our data and make a decission about what data do we have,
what is the quality of them and choose the column that can be usefull to get interesting
conclusions about this dataset.
'''

df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN
# 4                       Bells Beach  Surfing             male    M  NaN
#
#                                   Injury Fatal (Y/N)   Time   Species   \
# 0                  Minor injury to thigh           N  13h00        NaN
# 1                   Lacerations to hands           N  11h00        NaN
# 2               Lacerations to lower leg           N  10h43        NaN
# 3           Struck by fin on chest & leg           N    NaN        NaN
# 4  No injury: Knocked off board by shark           N    NaN  2 m shark
#
#         Investigator or Source                        pdf  \
# 0  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c            5993         NaN         NaN
# 1  2016.09.18.b            5992         NaN         NaN
# 2  2016.09.18.a            5991         NaN         NaN
# 3    2016.09.17            5990         NaN         NaN
# 4    2016.09.15            5989         NaN         NaN

# %% [markdown]
# Ok, we have a lot of data:
#
# About kinds of sharks, when it attacked people, where it was, what was this people doing while the attack was performed, the injuries and if it was fatal or not, name of the person, a refference about the source of the data aqduisition and other data about sources and files refferences.
#
# Let's check the quality of this data to be able to know what can be useful for us.

# %%
#Lets check about null values in columns and compare them with the size of our dataframe:
print('The size of our dataframe is:',df.shape)
null_values = df.isnull().sum()
null_values[null_values > 0]
# Out:
# The size of our dataframe is: (5992, 24)
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %% [markdown]
# We can see that there are two columns with almost 95% of rows with NaN values, this is unusefull for us.
#
# Afterwars we have tree columns with near to half of the values NaN, but it could contain data that can be used to get any conclussion as type of shark, the moment of the day when the attack was performed or the shark species which attacked.
# Anyway, as the dataset has other data stored with much more information in which we can focus on. We will discard Age, Time and Species.
#
# Other columns as Name, href formula, pdf or href have data that can't be used to make decissions or get conclussions. They have so heterogeneus strings data or in case of Case Number, case Number.1 and case Number.2 the data are so similar to the other, so we will discard them.

# %%
'''
We drop columns with more that 2600 Nan elements, that includes 'Unnamed: 22','Unnamed: 23',\
'Age', 'Time'and 'Species'
'''
drop_cols = list(null_values[null_values >=2600].index)
df = df.drop(drop_cols, axis=1)
'''
Next thing to do is drop other columns, that even having great quantity of data they are heterogeneous
strings or simiar to other columns.
'''
drop_cols = ['Name','href','href formula','pdf','Case Number.1','Case Number.2','original order']
df = df.drop(columns=drop_cols, axis=1)
#Let's check atual columns
print(df.columns)
#Let's check about NaN reaminig values.
null_values = df.isnull().sum()
null_values[null_values > 0]
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Injury', 'Fatal (Y/N)', 'Investigator or Source'],
#       dtype='object')
# Country                    43
# Area                      402
# Location                  496
# Activity                  527
# Sex                       567
# Injury                     27
# Fatal (Y/N)                19
# Investigator or Source     15
# dtype: int64

# %% [markdown]
# Now we have less NaN values and data that could be useful for us. Now it is necessary to check the column names in order to make easy work with it.

# %%
# Renaming wrong named columns
df.rename(columns={'Sex ':'Sex','Fatal (Y/N)':'Fatal','Investigator or Source':'Source'},inplace=True)
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex', 'Injury', 'Fatal', 'Source'],
#       dtype='object')

# %% [markdown]
# In this point it is necessary to start cleaning the received data. Let's start for the most homogeneus columns in order to do first the easier tasks.

# %%
#Type columns has values with the same meaning called by differents ways.
df['Type'].value_counts()
# Out:
# Unprovoked      4386
# Provoked         557
# Invalid          519
# Sea Disaster     220
# Boat             200
# Boating          110
# Name: Type, dtype: int64

# %%
df['Type'] = df['Type'].str.replace('Boating', 'Boat')
df['Type'].value_counts()
#Now Type column has uniform values.
# Out:
# Unprovoked      4386
# Provoked         557
# Invalid          519
# Boat             310
# Sea Disaster     220
# Name: Type, dtype: int64

# %%
#lets check Fatal column in order to clean those Data:
df['Fatal'].value_counts()
# Out:
# N          4315
# Y          1552
# UNKNOWN      94
#  N            8
# N             1
# F             1
# n             1
# #VALUE!       1
# Name: Fatal, dtype: int64

# %%
# Thre only should have three values: Y, N and UNKNOWN so let's clean them:
# first it is necessary to suprime empty spaces: 
df['Fatal'] = df['Fatal'].str.replace(' ', '').str.replace('F','Y').str.replace('#VALUE!','UNKNOWN').str.replace('n','N')
df['Fatal'].value_counts()
# Out:
# N          4325
# Y          1553
# UNKNOWN      95
# Name: Fatal, dtype: int64

# %%
# Let'se check the values in sex column:
df['Sex'].value_counts()
# Out:
# M      4835
# F       585
# M         2
# N         1
# .         1
# lli       1
# Name: Sex, dtype: int64

# %%
df['Sex'] = df['Sex'].str.replace(' ', '')

df = df.drop(df[(df['Sex'] == 'lli') | (df['Sex'] == '.') | (df['Sex'] == 'N')].index)
df['Sex'].value_counts()
# Out:
# M    4837
# F     585
# Name: Sex, dtype: int64

# %%
'''
After that it is necessary to drop the rows with more than 2 null values in order to get\
discard the elements wich don let us to make cnsisten conclusions.
'''


bad_indexes = get_poor_rows(df) 

df = drop_by_index(df, bad_indexes)

df.shape
# Out:
# (5882, 12)

# %%
# AS year is given in a specified column from Date lets take the month data and append it into a new column:
import re
df['Date']=df['Date'].str.replace(' ', '').str.replace('Reported', '')
list(df['Date'])
df['Month'] = get_month_from_date(df)

#lets drop null elements:
df = df.drop(df[df['Month'].isnull()].index)
df['Month'].isnull().sum()
#Let's drop Date column because now we get the information that we wanted.
df = df.drop(columns = 'Date')
df
# Out:
#        Case Number  Year        Type              Country  \
# 0     2016.09.18.c  2016  Unprovoked                  USA
# 1     2016.09.18.b  2016  Unprovoked                  USA
# 2     2016.09.18.a  2016  Unprovoked                  USA
# 3       2016.09.17  2016  Unprovoked            AUSTRALIA
# 4       2016.09.15  2016  Unprovoked            AUSTRALIA
# 5     2016.09.15.R  2016        Boat            AUSTRALIA
# 6       2016.09.11  2016  Unprovoked                  USA
# 7       2016.09.07  2016  Unprovoked                  USA
# 8       2016.09.06  2016  Unprovoked        NEW CALEDONIA
# 9     2016.09.05.b  2016  Unprovoked                  USA
# 10    2016.09.05.a  2016  Unprovoked            AUSTRALIA
# 11      2016.09.04  2016  Unprovoked                  USA
# 12      2016.09.01  2016  Unprovoked                  USA
# 13    2016.08.29.b  2016  Unprovoked                  USA
# 14    2016.08.29.a  2016  Unprovoked                  USA
# 15      2016.08.27  2016  Unprovoked              REUNION
# 16      2016.08.25  2016  Unprovoked                  USA
# 17      2016.08.07  2016  Unprovoked              BAHAMAS
# 18      2016.08.06  2016  Unprovoked                  USA
# 19      2016.08.04  2016  Unprovoked                  USA
# 20      2016.07.29  2016  Unprovoked                SPAIN
# 21    2016.07.28.R  2016  Unprovoked                CHINA
# 22      2016.07.28  2016        Boat            AUSTRALIA
# 23      2016.07.27  2016    Provoked                  USA
# 24      2016.07.26  2016  Unprovoked            AUSTRALIA
# 25      2016.07.24  2016  Unprovoked                JAPAN
# 26    2016.07.23.b  2016  Unprovoked            AUSTRALIA
# 27    2016.07.23.a  2016  Unprovoked              BAHAMAS
# 28      2016.07.20  2016    Provoked            AUSTRALIA
# 29      2016.07.17  2016        Boat                  USA
# ...            ...   ...         ...                  ...
# 5821    1817.06.24  1817  Unprovoked                  USA
# 5822    1817.06.15  1817  Unprovoked                INDIA
# 5824    1817.02.22  1817  Unprovoked            SRI LANKA
# 5825  1816.09.03.R  1816  Unprovoked                  USA
# 5827    1811.03.01  1811  Unprovoked                  NaN
# 5828    1807.01.12  1807  Unprovoked            AUSTRALIA
# 5829    1805.09.00  1805     Invalid                  USA
# 5831    1803.03.00  1803  Unprovoked            AUSTRALIA
# 5834    1788.05.10  1788        Boat            AUSTRALIA
# 5835    1787.07.05  1787  Unprovoked            St Helena
# 5836  1785.09.26.R  1785  Unprovoked              ENGLAND
# 5840  1771.07.12.R  1771  Unprovoked                  USA
# 5847    1742.12.17  1742  Unprovoked                  NaN
# 5848  1738.04.06.R  1738  Unprovoked                ITALY
# 5851    1703.03.26  1703  Unprovoked             BARBADOS
# 5874       ND-0151     0  Unprovoked               PANAMA
# 5895       ND-0115     0  Unprovoked          NEW ZEALAND
# 5909       ND.0095     0  Unprovoked      SOLOMON ISLANDS
# 5910       ND.0094     0  Unprovoked                KOREA
# 5911       ND.0093     0  Unprovoked     FRENCH POLYNESIA
# 5913       ND.0090     0  Unprovoked              VANUATU
# 5914       ND.0089     0    Provoked              VANUATU
# 5919       ND.0084     0  Unprovoked         SOUTH AFRICA
# 5921       ND.0082     0  Unprovoked               GREECE
# 5935       ND.0060     0  Unprovoked                  USA
# 5936       ND.0059     0  Unprovoked              BERMUDA
# 5947       ND.0047     0  Unprovoked  NORTH PACIFIC OCEAN
# 5978       ND.0014     0  Unprovoked                  USA
# 5979       ND.0013     0  Unprovoked         SOUTH AFRICA
# 5980       ND.0012     0  Unprovoked         SOUTH AFRICA
#
#                          Area  \
# 0                     Florida
# 1                     Florida
# 2                     Florida
# 3                    Victoria
# 4                    Victoria
# 5           Western Australia
# 6                     Florida
# 7                      Hawaii
# 8              North Province
# 9              South Carolina
# 10          Western Australia
# 11                    Florida
# 12                 California
# 13                    Florida
# 14                    Florida
# 15                        NaN
# 16                    Florida
# 17      New Providence Island
# 18                     Hawaii
# 19                    Florida
# 20          Alicante Province
# 21                  Hong Kong
# 22          Western Australia
# 23                    Florida
# 24            New South Wales
# 25           Kochi Prefecture
# 26                   Tasmania
# 27              Abaco Islands
# 28                 Queensland
# 29                    Alabama
# ...                       ...
# 5821           South Carolina
# 5822              Maharashtra
# 5824                      NaN
# 5825             Rhode Island
# 5827                      NaN
# 5828          New South Wales
# 5829                 New York
# 5831        Western Australia
# 5834          New South Wales
# 5835                      NaN
# 5836                   Sussex
# 5840                      NaN
# 5847                      NaN
# 5848                   Sicily
# 5851          Southwest coast
# 5874  Bocas del Toro Province
# 5895             North Island
# 5909         Malaita Province
# 5910              South Korea
# 5911                 Tuamotus
# 5913         Malampa Province
# 5914         Malampa Province
# 5919    Eastern Cape Province
# 5921          Island of Volos
# 5935               California
# 5936                    Paget
# 5947                      NaN
# 5978          North Carolina
# 5979            KwaZulu-Natal
# 5980            KwaZulu-Natal
#
#                                              Location  \
# 0                    New Smyrna Beach, Volusia County
# 1                    New Smyrna Beach, Volusia County
# 2                    New Smyrna Beach, Volusia County
# 3                                    Thirteenth Beach
# 4                                         Bells Beach
# 5                                             Bunbury
# 6                       Ponte Vedra, St. Johns County
# 7                                        Makaha, Oahu
# 8                                              Koumac
# 9     Kingston Plantation, Myrtle Beach, Horry County
# 10                                           Injidup
# 11                   New Smyrna Beach, Volusia County
# 12          Refugio State Beach, Santa Barbara County
# 13                   New Smyrna Beach, Volusia County
# 14                   New Smyrna Beach, Volusia County
# 15                                       Boucan Canot
# 16                      Ponte Vedra, St. Johns County
# 17                                             Nassau
# 18                                               Maui
# 19                   New Smyrna Beach, Volusia County
# 20                                   Arenales del Sol
# 21                                                NaN
# 22                                        Near Albany
# 23                        Florida Keys, Monroe County
# 24                             Sharpes Beach, Ballina
# 25                                        Irino Beach
# 26                                      Clifton Beach
# 27                                   Green Turtle Cay
# 28              20 k off The Spit, off the Gold Coast
# 29                                 8 miles off Mobile
# ...                                               ...
# 5821             Charleston Harbor, Charleston County
# 5822                              Bombay (now Mumbai)
# 5824                                   Gulf of Mannar
# 5825                                   Bristol Harbor
# 5827                                              NaN
# 5828                       Cockle Bay, Sydney Harbour
# 5829                       Sag Harbor, Suffolk County
# 5831                 Hamelin Harbour, at Faure Island
# 5834                                    Sydney Harbor
# 5835                                    Landing Place
# 5836                                         Brighton
# 5840                                       Damiscotte
# 5847                                     Carlisle Bay
# 5848                                Strait of Messina
# 5851                                     Carlisle Bay
# 5874                                   Red Frog Beach
# 5895                         Point Halsey, Wellington
# 5909                                  Waibana Passage
# 5910                                     Cheju Island
# 5911                                         Rangiroa
# 5913                                         Malakula
# 5914                                  Hokai, Malakula
# 5919                            Keiskamma River mouth
# 5921                                    Eastern shore
# 5935                        Capistrano, Orange County
# 5936                                     Paget Parish
# 5947                                      Wake Island
# 5978          Somewhere between Hatteras and Beaufort
# 5979                                           Durban
# 5980                                           Durban
#
#                                    Activity  Sex  \
# 0                                   Surfing    M
# 1                                   Surfing    M
# 2                                   Surfing    M
# 3                                   Surfing    M
# 4                                   Surfing    M
# 5                                   Fishing  NaN
# 6                                    Wading    M
# 7                                  Swimming    F
# 8                              Kite surfing    M
# 9                           Boogie boarding    F
# 10                                  Surfing    M
# 11                            Body boarding    M
# 12                             Spearfishing    M
# 13                                  Surfing    M
# 14                                  Surfing    M
# 15                                  Surfing    M
# 16                                   Wading    M
# 17                               Snorkeling    M
# 18                        SUP Foil boarding    M
# 19                                  Surfing    M
# 20                                 Swimming    M
# 21                                 Swimming    M
# 22                                 Kayaking    M
# 23                               Lobstering    M
# 24                                  Surfing    M
# 25                                  Surfing    M
# 26                                  Surfing    M
# 27                             Spearfishing    M
# 28                                  Fishing    M
# 29    Fishing in Alabama Deep Fishing Rodeo  NaN
# ...                                     ...  ...
# 5821                               Swimming    M
# 5822                               Swimming    M
# 5824                            Conch diver    M
# 5825                               Swimming  NaN
# 5827                         Fell overboard    M
# 5828                                    NaN    M
# 5829                                    NaN    M
# 5831                                    NaN    M
# 5834                                Fishing  NaN
# 5835                               Swimming    M
# 5836                                    NaN    M
# 5840                                Fishing    M
# 5847                               Swimming    M
# 5848                               Swimming    M
# 5851                               Swimming    M
# 5874                              Swimming/    M
# 5895                                    NaN    M
# 5909                                 Diving  NaN
# 5910                                 Diving    F
# 5911                                Fishing    M
# 5913                                    NaN    F
# 5914    Attempting to drive shark from area    M
# 5919               Crossing river on a raft    M
# 5921                               Swimming    F
# 5935                                    NaN    F
# 5936                          Spearfishing     M
# 5947    Fishing, wading with string of fish    M
# 5978                               Swimming    M
# 5979                                Fishing    M
# 5980                                 Wading    M
#
#                                                  Injury Fatal  \
# 0                                 Minor injury to thigh     N
# 1                                  Lacerations to hands     N
# 2                              Lacerations to lower leg     N
# 3                          Struck by fin on chest & leg     N
# 4                 No injury: Knocked off board by shark     N
# 5              Shark rammed boat. No injury to occupant     N
# 6                                   Minor injury to arm     N
# 7              Severe lacerations to shoulder & forearm     N
# 8                                                 FATAL     Y
# 9            Lacerations & punctures to lower right leg     N
# 10              No inury, board broken in half by shark     N
# 11                                          Foot bitten     N
# 12                          Two toes broken & lacerated     N
# 13                            Lacerations to right foot     N
# 14                                Minor injury to ankle     N
# 15            Right arm severed, ankle severely bitten      N
# 16                                Minor injury to ankle     N
# 17                              Lacerations to left leg     N
# 18                     No inury, shark & board collided     N
# 19                                       Big toe bitten     N
# 20                            Lacerations to right hand     N
# 21                                   Lacerations to leg     N
# 22             No injury, shark nudged kayak repeatedly     N
# 23         Laceration to left forearm PROVOKED INCIDENT     N
# 24    No injury. Leg rope severed, knocked off board...     N
# 25                              Lacerations to left leg     N
# 26                            Calf bumped but no injury     N
# 27                    Lacerations to face and right leg     N
# 28    Laceration to left calf from hooked shark PROV...     N
# 29                  No injury, shark bit trolling motor     N
# ...                                                 ...   ...
# 5821                                              FATAL     Y
# 5822                                              FATAL     Y
# 5824                                     Abdomen bitten     N
# 5825                                              FATAL     Y
# 5827                                              FATAL     Y
# 5828                                           Survived     N
# 5829          human remains (male) found in sharks gut     Y
# 5831  Shark knocked him down & tore clothing of the ...     N
# 5834   No injury to occupants, shark bit oar and rudder     N
# 5835                                              FATAL     Y
# 5836                 Human remains recovered from shark     Y
# 5840                                              FATAL     Y
# 5847                                              FATAL     Y
# 5848                                              FATAL     Y
# 5851  Hand and foot severely bitten, surgically ampu...     N
# 5874                                              FATAL     Y
# 5895                                              FATAL     Y
# 5909                      Lacerations to hands and knee     N
# 5910   FATAL, injured while diving, then shark bit her      Y
# 5911  Speared a shark, fell overboard and another sh...     N
# 5913                                              FATAL     Y
# 5914  Speared shark broke outrigger of canoe throwin...     N
# 5919                                 FATAL, leg severed     Y
# 5921                                              FATAL     Y
# 5935                                        Leg injured     N
# 5936                  Shoulder abraded by skin of shark     N
# 5947                                           Survived     N
# 5978                                         "Lost leg"     N
# 5979  FATAL, body not recovered but shark was caught...     Y
# 5980                     FATAL, leg stripped of flesh       Y
#
#                                                  Source Month
# 0                           Orlando Sentinel, 9/19/2016   sep
# 1                           Orlando Sentinel, 9/19/2016   sep
# 2                           Orlando Sentinel, 9/19/2016   sep
# 3                                    The Age, 9/18/2016   sep
# 4                                    The Age, 9/16/2016   sep
# 5                            West Australian, 9/15/2016   sep
# 6                                   News4Jax, 9/11/2016   sep
# 7                             Hawaii News Now, 9/7/2016   sep
# 8                                TVANouvelles, 9/6/2016   sep
# 9                                     C. Creswell, GSAF   sep
# 10                                  Perth Now, 9/5/2016   sep
# 11                           Orlando Sentinel, 9/7/2016   sep
# 12                                     R. Collier, GSAF   sep
# 13                              News Channel 8, 8/30/16   aug
# 14                              News Channel 8, 8/30/16   aug
# 15                                 LaDepeche, 8/29/2016   aug
# 16                          First Coast News, 7/25/2016   aug
# 17                                       ABC, 8/11/2016   aug
# 18                                        SUP, 8/9/2015   aug
# 19                                   News 965, 8/5/2016   aug
# 20                            Informacion.es, 7/29/2016   jul
# 21                                  Klassick, 7/28/2016   jul
# 22                             ABC Australia, 7/28/2016   jul
# 23                           Tampa Bay Times, 7/27/2016   jul
# 24                       Gold Coast Bulletin, 7/28/2016   jul
# 25                               Japan Times, 7/25/2016   jul
# 26                                       C. Black, GSAF   jul
# 27                                      KWTX, 7/23/2016   jul
# 28                                 Nine News, 7/20/2016   jul
# 29                                    Al.com, 7/19/2016   jul
# ...                                                 ...   ...
# 5821                               The Times, 6/25/1817   jun
# 5822                     Edinburgh Advertiser. 2/3/1818   jun
# 5824                                         J. Kennedy   feb
# 5825                      Connecticut Courant, 9/3/1816   ept
# 5827                         Journal of Captain Marryat   mar
# 5828                                     J. Green, p.31   jan
# 5829                               S.L. Mitchill (1814)   sep
# 5831  F.  Peron ref in G.P. Whitley (Fishes of Austr...   mar
# 5834  G.P. Whitley citing J. Cobley, Sydney Cove, p....   may
# 5835  H.R. Janisch (1885), Extracts from the St. Hel...   jul
# 5836                                     C. Moore, GSAF   sep
# 5840                                     C. Moore, GSAF   jul
# 5847                                     C. Moore, GSAF   dec
# 5848                                     C. Moore, GSAF   apr
# 5851                           W.R.Cutter, Vol.1, p.252   mar
# 5874                            C. Mendieta & A. Duarte   oct
# 5895                             Evening Post, 6/8/1912   jun
# 5909                     Islands Magazine, 2/1998, p.76   feb
# 5910                            K. Amsler, Divernet.com   may
# 5911                                           J. Windh   mar
# 5913                                           S. Combs   aug
# 5914                                           S. Combs   aug
# 5919                        Whitaker, The Sun, 1/3/1967   jan
# 5921                   Sydney Morning Herald, 5/8/1965    may
# 5935        B. Walton, Sun (San Bernardino), 6/19/1959    jun
# 5936  Mentioned in letter from L. S. Mowbray dated 4...   apr
# 5947  J. Oetzel, Skin Diver Magazine, March 1956, p.19    mar
# 5978     C. Creswell, GSAF; Wilmington Star, 7/17/1916    jul
# 5979                       Rural New Yorker, 7/19/1913    jul
# 5980                        Rural New Yorker, 7/19/1913   jul
#
# [5384 rows x 12 columns]

# %%
# Out:
# 0

# %%
df.shape
# Out:
# (5384, 13)
