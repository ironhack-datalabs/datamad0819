# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
import sqlalchemy as db
import getpass

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
#password = getpass.getpass("Insert your mysql root password: ") no es necesario porque la contraseña es pública
engine = db.create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/stats')

# %% [markdown]
# #### 4. Import the users table

# %%
dfUsers = pd.read_sql_query("select * from users", engine)
dfUsers
# Out:
#           Id  Reputation        CreationDate     DisplayName  \
# 0         -1           1 2010-07-19 06:55:26       Community
# 1          2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27          Emmett
# 4          5        6792 2010-07-19 19:03:57           Shane
# ...      ...         ...                 ...             ...
# 40320  55743           1 2014-09-13 21:03:50       AussieMeg
# 40321  55744           6 2014-09-13 21:39:30       Mia Maria
# 40322  55745         101 2014-09-13 23:45:27    tronbabylove
# 40323  55746         106 2014-09-14 00:29:41             GPP
# 40324  55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
dfUsers = dfUsers.rename(columns = {"Id":"userId"})
dfUsers
# Out:
#        userId  Reputation        CreationDate     DisplayName  \
# 0          -1           1 2010-07-19 06:55:26       Community
# 1           2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101 2010-07-19 19:03:27          Emmett
# 4           5        6792 2010-07-19 19:03:57           Shane
# ...       ...         ...                 ...             ...
# 40320   55743           1 2014-09-13 21:03:50       AussieMeg
# 40321   55744           6 2014-09-13 21:39:30       Mia Maria
# 40322   55745         101 2014-09-13 23:45:27    tronbabylove
# 40323   55746         106 2014-09-14 00:29:41             GPP
# 40324   55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
dfPosts = pd.read_sql_query("select * from posts", engine)

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
dfPosts = dfPosts.rename(columns = {"Id":"postId","OwnerUserId":"userId"})
dfPosts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0       1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1       2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2       3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3       4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4       5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  userId  \
# 0  <p>How should I elicit prior distributions fro...     8.0
# 1  <p>In many different statistical methods there...    24.0
# 2  <p>What are some valuable Statistical Analysis...    18.0
# 3  <p>I have two groups of data.  Each with a dif...    23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#       LasActivityDate                                              Title  ...  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
littleUsers =dfUsers[["userId","Reputation","Views","UpVotes","DownVotes"]]
littlePosts = dfPosts[["postId", "Score","userId","ViewCount","CommentCount"]]

#x = littlePosts.groupby("userId","postId").agg({'Score':'mean','ViewCount':'min',"CommentCount":"sum"})

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
#usersPosts =dfUsers[["userId","Reputation","Views","UpVotes","DownVotes"]].join(dfPosts[["postId", "Score","userId","ViewCount","CommentCount"]],on = "userId", how = "left", lsuffix='_left', rsuffix='_right')
usersPosts = littleUsers.merge(littlePosts, left_on='userId', right_on='userId')
#dfUsers[["userId","Reputation","Views","UpVotes","DownVotes"]].join(dfPosts[["postId", "Score","userId","ViewCount","CommentCount"]],on = "userId", how = "left", lsuffix='_left', rsuffix='_right')
usersPosts.columns
# Out:
# Index(['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes', 'postId',
#        'Score', 'ViewCount', 'CommentCount'],
#       dtype='object')

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
null_cols = usersPosts.isnull().sum()
null_cols[null_cols > 0]
# Out:
# ViewCount    48396
# dtype: int64

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
#Cálculo del % de valores perdidos en la columna
print("% de valores  anómalos en la columna",100*48396/(len(usersPosts["ViewCount"].values.tolist())))
#Pienso que en este caso se puede limpiar porque los datos nulos representan el 53% de la columna y no se han dado
#instrucciones que hagan pensar que podamos necesitar esa columna
usersPosts = usersPosts.drop("ViewCount",axis=1)
usersPosts.head()
#la otra opción sería sustituir los valores perdidos por lo que deseemos, en este caso la columna es un contador
#por lo que parece razonable sustituirlos por 0, aunque al haber tantos pienso que la mejor opción es dropear la
#columna como dije arriba.
# Out:
# % de valores  anómalos en la columna 53.42665371368012
#    userId  Reputation  Views  UpVotes  DownVotes  postId  Score  CommentCount
# 0      -1           1      0     5007       1920    2175      0             0
# 1      -1           1      0     5007       1920    8576      0             0
# 2      -1           1      0     5007       1920    8578      0             0
# 3      -1           1      0     5007       1920    8981      0             0
# 4      -1           1      0     5007       1920    8982      0             0

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
#Formula de outliers
for columna in usersPosts.columns.tolist():
    usersPosts[columna] = usersPosts[columna].astype("int")

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.

# %%
stats = usersPosts.describe().transpose()
stats["IQr"] = stats['75%'] - stats['25%']
stats
# Out:
#                 count          mean           std   min       25%      50%  \
# userId        90584.0  16546.764727  15273.367108  -1.0   3437.00  11032.0
# Reputation    90584.0   6282.395412  15102.268670   1.0     60.00    396.0
# Views         90584.0   1034.245176   2880.074012   0.0      5.00     45.0
# UpVotes       90584.0    734.315718   2050.869327   0.0      1.00     22.0
# DownVotes     90584.0     33.273249    134.936435   0.0      0.00      0.0
# postId        90584.0  56539.080522  33840.307529   1.0  26051.75  57225.5
# Score         90584.0      2.780767      4.948922 -19.0      1.00      2.0
# CommentCount  90584.0      1.894650      2.638704   0.0      0.00      1.0
#
#                    75%       max       IQr
# userId        27700.00   55746.0  24263.00
# Reputation     4460.00   87393.0   4400.00
# Views           514.25   20932.0    509.25
# UpVotes         283.00   11442.0    282.00
# DownVotes         8.00    1920.0      8.00
# ...

# %%
outliers = pd.DataFrame(columns=usersPosts.columns)

for col in stats.index:
    iqr = stats.at[col,'IQr']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = usersPosts[(usersPosts[col] < lower) | 
                   (usersPosts[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#       CommentCount DownVotes       Outlier Reputation Score UpVotes Views  \
# 1155             0       126    Reputation      14082    25    4235  3320
# 1156             0       126    Reputation      14082     5    4235  3320
# 1157             1       126    Reputation      14082     7    4235  3320
# 1158             3       126    Reputation      14082     6    4235  3320
# 1159             0       126    Reputation      14082     7    4235  3320
# ...            ...       ...           ...        ...   ...     ...   ...
# 90274           10         0  CommentCount         13     2       0     0
# ...

# %%
outliers.to_csv("./outliers.csv")
